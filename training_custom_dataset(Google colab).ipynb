# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls '/content/drive/My Drive/yolo_custom_model_Training'
# Out:
# backup	  chart.png		   custom_data	 custom_data1.zip  darknet
# bad.list  chart_yolov3_custom.png  custom_data1  custom_weight	   testimages

# %%
# unzipping the file containing the images
#!unzip '/content/drive/My Drive/yolo_custom_model_Training/custom_data1.zip' -d '/content/drive/My Drive/yolo_custom_model_Training/'

# %%
# cloning the darknet repository
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/yolo_custom_model_Training/darknet'

# %%
# %cd '/content/drive/My Drive/yolo_custom_model_Training/darknet'
# Out:
# /content/drive/My Drive/yolo_custom_model_Training/darknet

# %%
# change makefile to have GPU and OPENCV enabled
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# Verify cv2 version
import cv2
cv2.__version__
# Out:
# '4.1.2'

# %%
# Compile make file
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd '/content/drive/My Drive/yolo_custom_model_Training'
# Out:
# /content/drive/My Drive/yolo_custom_model_Training

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# Creating train,test,labelled,classes.names files
# !python custom_data1/creating-files-data-and-name.py
# !python custom_data1/creating-train-and-test-txt-files.py

# %%
# !ls
# Out:
# backup	  chart.png		   custom_data	 custom_data1.zip  darknet
# bad.list  chart_yolov3_custom.png  custom_data1  custom_weight	   testimages

# %%
# Training the model
#!darknet/darknet detector train custom_data1/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/yv3cw.weights -dont_show
# !darknet/darknet detector train custom_data1/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/yv3clwnew.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.856117), count: 3, class_loss = 0.003856, iou_loss = 0.030927, total_loss = 0.034783
#  total_bbox = 58151, rewritten_bbox = 0.042992 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.728964), count: 2, class_loss = 0.023665, iou_loss = 0.106405, total_loss = 0.130070
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.907614), count: 2, class_loss = 0.001716, iou_loss = 0.009327, total_loss = 0.011043
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.928879), count: 2, class_loss = 0.000007, iou_loss = 0.007692, total_loss = 0.007698
# ...
